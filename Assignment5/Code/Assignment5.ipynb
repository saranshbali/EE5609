# %% [markdown]
# The given second degree equation is:
#
# $x^2 -y^2 -2xy -1 =0$
#
# Here a = 1, b =-1, c= -1, d= 0, e=0 and f = -1

# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA
import warnings
import math as m
warnings.filterwarnings("ignore")

# %%
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111, aspect='equal')
len = 2000
y= np.linspace(-10,10,len)
#Hyperbola parameters
# given equation values x^TVx+2u^Tx+f=0
V1 = np.array(([1,-1],[-1,-1]))
u1 = np.array(([0,0]))
f1 = -1
#Reflection matrix
R1 = np.array(([0,1],[1,0]))
#Eigenvalues and eigenvectors
D_vec1,P1 = LA.eig(V1) 
D1= np.diag(D_vec1)
#Generating the positive hyperbola at the origin
x1 = np.sqrt((1-D_vec1[1]*(y**2))/D_vec1[0])
#Affine transformation parameters
c1 = -LA.inv(V1)@u1 #c=-V^(-1)u
k1 = np.sqrt(np.abs(f1 +u1@c1 ))
print("centre",c1)
#Affine transform 
z1 = np.hstack((np.vstack((x1,y)),np.vstack((-x1,y))))
x_vec1 = k1*P1.T@R1@z1+c1[:,None]
#centre and modified centre 
xc=[0]
yc=[0]
# plotting given hyperbola 
plt.plot(x_vec1[0,0:len],x_vec1[1,0:len], color='b')
plt.plot(x_vec1[0,len:2*len],x_vec1[1,len:2*len], color='b', label = 'Hyperbola ---> $x^2-2xy-y^2-1=0$')

plt.plot(xc[0],yc[0],marker='o',color='black',label='centre (0,0)') # origin point 

# x-y axis with origin (0,0)
plt.axhline(0, color='black')
plt.axvline(0, color='black')

plt.xlabel('$x-axis$');plt.ylabel('$y-axis$')

plt.xlim([-10, 10])
plt.ylim([-10,10])

#annotate centre points 
for x,y in zip(xc, yc):
    label = '  c ( %d, %d )' % (x, y)
    ax.text(x, y, label,color='r')

plt.legend(bbox_to_anchor=(0.8, 1), loc='lower center')
plt.grid()

plt.show()
# Out:
# centre [0. 0.]

# %%
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111, aspect='equal')
len = 2000
y= np.linspace(-10,10,len)
#Hyperbola parameters
# given equation values x^TVx+2u^Tx+f=0
V1 = np.array(([0,1/2],[1/2,0]))
u1 = np.array(([0,0]))
f1 = -c
#Reflection matrix
R1 = np.array(([0,1],[1,0]))
#Eigenvalues and eigenvectors
D_vec1,P1 = LA.eig(V1) 
D1= np.diag(D_vec1)
#Generating the positive hyperbola at the origin
x1 = np.sqrt((1-D_vec1[1]*(y**2))/D_vec1[0])
#Affine transformation parameters
c1 = -LA.inv(V1)@u1 #c=-V^(-1)u
k1 = np.sqrt(np.abs(f1 +u1@c1 ))
print("centre",c1)
#Affine transform 
z1 = np.hstack((np.vstack((x1,y)),np.vstack((-x1,y))))
x_vec1 = k1*P1.T@R1@z1+c1[:,None]
#centre and modified centre 
xc=[0]
yc=[0]
# plotting given hyperbola 

plt.grid()
plt.plot(x_vec1[0,0:len],x_vec1[1,0:len], color='b')
plt.plot(x_vec1[0,len:2*len],x_vec1[1,len:2*len], color='b', label = 'Hyperbola ---> $xy=c$')
plt.plot(xc[0],yc[0],marker='o',color='black',label='centre (0,0)') # origin point 

# x-y axis with origin (0,0)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.xlabel('$x-axis$');plt.ylabel('$y-axis$')

plt.xlim([-10, 10])
plt.ylim([-10,10])

#annotate centre points 
for x,y in zip(xc, yc):
    label = '  c ( %d, %d )' % (x, y)
    ax.text(x, y, label,color='r')

plt.legend(bbox_to_anchor=(0.8, 1), loc='lower center')
plt.grid()

plt.show()
# Out:
# centre [0. 0.]
